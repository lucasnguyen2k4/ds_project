# %%
import pandas as pd
import numpy as np

# %%
directory = "C:/Users/lCKUG/Downloads/ds_project-patch-1"
#load multi index data
df = pd.read_csv(directory + "/weather.csv", header=[0, 1], index_col=0)
df2 = pd.read_csv(directory + "/cities.csv")
df3 = pd.read_csv(directory + "/air_quality.csv", header=[0, 1], index_col=0)

# %%
#convert to normal index
dfs = df.stack(level=0).reset_index()
dfs.rename(columns={'level_1': 'location'}, inplace=True)

df3s = df3.stack(level=0).reset_index()
df3s.rename(columns={'level_1': 'location'}, inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_16408\1286927556.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   dfs = df.stack(level=0).reset_index()
# C:\Users\DELL\AppData\Local\Temp\ipykernel_16408\1286927556.py:4: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df3s = df3.stack(level=0).reset_index()
#                time                location  temperature_2m  \
# 0  2020-11-28T00:00       Biên Hòa, Vietnam            25.2
# 1  2020-11-28T00:00  Buôn Ma Thuột, Vietnam            21.7
# 2  2020-11-28T00:00       Bạc Liêu, Vietnam            25.0
# 3  2020-11-28T00:00      Bắc Giang, Vietnam            16.4
# 4  2020-11-28T00:00        Bắc Kạn, Vietnam            15.1
#
#    relative_humidity_2m  dew_point_2m  rain  snowfall  surface_pressure  \
# 0                  80.0          21.4   0.0       0.0            1010.4
# 1                  88.0          19.7   0.0       0.0             960.9
# 2                  89.0          23.1   0.0       0.0            1010.8
# 3                  71.0          11.0   0.0       0.0            1022.3
# 4                  80.0          11.6   0.0       0.0            1002.8
#
#    cloud_cover  wind_speed_10m  wind_direction_10m
# 0          7.0             7.7                41.0
# 1         59.0             9.7                90.0
# 2         14.0             8.8                19.0
# 3        100.0            13.2                22.0
# 4         91.0            15.3                43.0

# %% [markdown]
# ## Data exploration

# %%
dfs.columns
# Out:
# Index(['time', 'location', 'temperature_2m', 'relative_humidity_2m',
#        'dew_point_2m', 'rain', 'snowfall', 'surface_pressure', 'cloud_cover',
#        'wind_speed_10m', 'wind_direction_10m'],
#       dtype='object')

# %%
max_values = dfs.max()
mean = dfs.mean()
max_values

# %%
mean

# %%
dfs.info
# Out:
# <bound method DataFrame.info of                      time  temperature_2m  relative_humidity_2m  dew_point_2m  \
# 0        2020-11-28T00:00            25.2                  80.0          21.4
# 1        2020-11-28T00:00            21.7                  88.0          19.7
# 2        2020-11-28T00:00            25.0                  89.0          23.1
# 3        2020-11-28T00:00            16.4                  71.0          11.0
# 4        2020-11-28T00:00            15.1                  80.0          11.6
# ...                   ...             ...                   ...           ...
# 2165242  2024-10-30T00:00            17.0                  90.0          15.4
# 2165243  2024-10-30T00:00            24.6                  87.0          22.3
# 2165244  2024-10-30T00:00            22.4                  92.0          21.0
# 2165245  2024-10-30T00:00            21.6                  89.0          19.8
# 2165246  2024-10-30T00:00            24.1                  92.0          22.7
#
#          rain  snowfall  surface_pressure  cloud_cover  wind_speed_10m  \
# 0         0.0       0.0            1010.4          7.0             7.7
# 1         0.0       0.0             960.9         59.0             9.7
# 2         0.0       0.0            1010.8         14.0             8.8
# 3         0.0       0.0            1022.3        100.0            13.2
# 4         0.0       0.0            1002.8         91.0            15.3
# ...       ...       ...               ...          ...             ...
# 2165242   0.0       0.0             852.9         53.0            14.1
# 2165243   0.0       0.0            1006.9         85.0             6.4
# 2165244   0.7       0.0            1008.6        100.0            20.2
# 2165245   3.7       0.0            1008.6        100.0            27.6
# 2165246   0.0       0.0            1001.0         13.0             1.5
#
#          wind_direction_10m       province  country
# 0                      41.0       Biên Hòa  Vietnam
# 1                      90.0  Buôn Ma Thuột  Vietnam
# 2                      19.0       Bạc Liêu  Vietnam
# 3                      22.0      Bắc Giang  Vietnam
# 4                      43.0        Bắc Kạn  Vietnam
# ...                     ...            ...      ...
# 2165242               292.0         Đà Lạt  Vietnam
# 2165243               281.0        Đà Nẵng  Vietnam
# 2165244               291.0        Đông Hà  Vietnam
# 2165245               299.0       Đồng Hới  Vietnam
# 2165246               315.0      Đồng Xoài  Vietnam
#
# [2165247 rows x 12 columns]>

# %%
df2.columns
# Out:
# Index(['city', 'city_ascii', 'lat', 'lng', 'country', 'iso2', 'iso3',
#        'admin_name', 'capital', 'population', 'id'],
#       dtype='object')

# %%
max_values = df3s.max()
mean = df3s.mean()
max_values

# %%
mean

# %%
df3s.head(100)
# Out:
#                    time      co    no2      o3    so2  pm2_5   pm10  \
# 0   2020-11-28 00:00:00  363.83   6.51   33.26   3.76   8.60  12.78
# 1   2020-11-28 00:00:00  473.98   7.88   30.76   4.17  14.06  17.11
# 2   2020-11-28 00:00:00  547.41   6.94   49.35   1.62  28.24  39.26
# 3   2020-11-28 00:00:00  554.09  10.11   22.71   5.66  24.91  28.58
# 4   2020-11-28 00:00:00  427.25   4.50   21.64   1.36  17.84  19.46
# ..                  ...     ...    ...     ...    ...    ...    ...
# 95  2020-11-28 01:00:00  327.11   2.25   13.05   0.98  11.61  13.79
# 96  2020-11-28 01:00:00  741.01  21.42   15.38  16.93  34.28  41.27
# 97  2020-11-28 01:00:00  554.09   2.51   50.78   2.38  34.99  35.41
# 98  2020-11-28 01:00:00  397.21   2.04   68.67   1.36  25.19  26.18
# 99  2020-11-28 01:00:00  407.22   1.80  101.57   2.53  33.78  36.92
#
#          province   country
# 0        Biên Hòa   Vietnam
# 1   Buôn Ma Thuột   Vietnam
# 2        Bạc Liêu   Vietnam
# 3       Bắc Giang   Vietnam
# 4         Bắc Kạn   Vietnam
# ..            ...       ...
# 95     Phan Thiết   Vietnam
# 96         Phủ Lý   Vietnam
# 97         Pleiku   Vietnam
# 98       Quy Nhơn   Vietnam
# 99     Quảng Ngãi   Vietnam
#
# [100 rows x 9 columns]

# %%
dfs[['province', 'country']] = dfs['location'].str.split(',', expand=True)

# %%
dfs = dfs.drop(columns=['location'])

# %%
df3s[['province', 'country']] = df3s['location'].str.split(',', expand=True)
df3s = df3s.drop(columns=['location'])

# %%
df3s.head()
# Out:
#                   time      co    no2     o3   so2  pm2_5   pm10  \
# 0  2020-11-28 00:00:00  363.83   6.51  33.26  3.76   8.60  12.78
# 1  2020-11-28 00:00:00  473.98   7.88  30.76  4.17  14.06  17.11
# 2  2020-11-28 00:00:00  547.41   6.94  49.35  1.62  28.24  39.26
# 3  2020-11-28 00:00:00  554.09  10.11  22.71  5.66  24.91  28.58
# 4  2020-11-28 00:00:00  427.25   4.50  21.64  1.36  17.84  19.46
#
#         province   country
# 0       Biên Hòa   Vietnam
# 1  Buôn Ma Thuột   Vietnam
# 2       Bạc Liêu   Vietnam
# 3      Bắc Giang   Vietnam
# 4        Bắc Kạn   Vietnam

# %%
dfs.to_csv(directory + "/we2.csv")
df3s.to_csv(directory + "/ar2.csv")
